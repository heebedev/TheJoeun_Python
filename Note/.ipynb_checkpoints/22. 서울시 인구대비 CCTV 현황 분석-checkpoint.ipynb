# %% [markdown]
# ## Pandas를 활용한 서울시 CCTV 현황 부석 및 인구 현황 분석

# %%
# module 불러오기
import pandas as pd
import numpy as np

# %%
## CCTV 설치 현황

CCTV_Seoul = pd.read_excel("../Data/CCTV_in_Seoul_2018.xlsx")
CCTV_Seoul.head()
# Out:
#    기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
CCTV_Seoul.tail()
# Out:
#     기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 20  용산구  2063    1279.0  152.0  201.0    107    102     89     60     73
# 21  은평구  2962    1365.0   83.0   99.0    343    180    296    229    367
# 22  종로구  1471       8.0    7.0  599.0    132    195    148    281    101
# 23   중구  1544      25.0  165.0  114.0     80    245    270    317    328
# 24  중랑구  1068       NaN    NaN    NaN    770    102    121     66      9

# %%
#CCTV_SEoul의 컬럼명 확인
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2011년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년'],
#       dtype='object')

# %%
# 첫번째 컬럼명
CCTV_Seoul.columns[0]
# Out:
# '기관명'

# %%
# 컬럼명인 기관명을 구별이라고 변경하기
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:'구별'}, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
# Nan데이터의 위치 및 내용 확인 : 2011년 이전 컬럼

# %%
CCTV_Seoul[CCTV_Seoul['2011년 이전'].isnull()]
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 10  동대문구  2003       NaN    NaN    NaN   1326    111    233    136    197
# 24   중랑구  1068       NaN    NaN    NaN    770    102    121     66      9

# %%
CCTV_Seoul[CCTV_Seoul.iloc[:,2].isnull()]
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 10  동대문구  2003       NaN    NaN    NaN   1326    111    233    136    197
# 24   중랑구  1068       NaN    NaN    NaN    770    102    121     66      9

# %%
#2011년 이전~2018년 까지의 컬럼을 반복문을 이용한 NaN 갯수 파악하기

for i in range(2,10) :
    print(CCTV_Seoul.columns[i], ':', len(CCTV_Seoul[CCTV_Seoul.iloc[:,i].isnull()]))
# Out:
# 2011년 이전 : 0
# 2012년 : 0
# 2013년 : 0
# 2014년 : 0
# 2015년 : 0
# 2016년 : 0
# 2017년 : 0
# 2018년 : 0

# %%
# Nan을 0으로 변환

CCTV_Seoul = CCTV_Seoul.fillna(0)

for i in range(2,10) :
    print(CCTV_Seoul.columns[i], ':', len(CCTV_Seoul[CCTV_Seoul.iloc[:,i].isnull()]))
# Out:
# 2011년 이전 : 0
# 2012년 : 0
# 2013년 : 0
# 2014년 : 0
# 2015년 : 0
# 2016년 : 0
# 2017년 : 0
# 2018년 : 0

# %%
# 데이터 불러오기
pop_Seoul = pd.read_excel("../Data/population_in_Seoul_2020.xlsx")
pop_Seoul.head()
# Out:
#      report Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        기간        자치구         세대         인구         인구         인구         인구
# 1        기간        자치구         세대         합계         합계         합계        한국인
# 2        기간        자치구         세대          계         남자         여자          계
# 3  2020.1/4         합계    4354006   10013781    4874995    5138786    9733655
# 4  2020.1/4        종로구      74151     161984      78271      83713     151217
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0         인구         인구         인구          인구          인구       세대당인구
# 1        한국인        한국인      등록외국인       등록외국인       등록외국인       세대당인구
# 2         남자         여자          계          남자          여자       세대당인구
# 3    4742217    4991438     280126      132778      147348        2.24
# 4      73704      77513      10767        4567        6200        2.04
#
#   Unnamed: 13
# 0    65세이상고령자
# 1    65세이상고령자
# 2    65세이상고령자
# ...

# %%
# 데이터 불러오기
pop_Seoul = pd.read_excel("../Data/population_in_Seoul_2020.xlsx", header = 3, usecols = "B,D,G,J,N")
pop_Seoul.head()
# Out:
#    자치구         계      계.1     계.2  65세이상고령자
# 0   합계  10013781  9733655  280126   1518239
# 1  종로구    161984   151217   10767     28073
# 2   중구    136469   126175   10294     23794
# 3  용산구    246165   229579   16586     39439
# 4  성동구    307193   299042    8151     44728

# %%
# 열(컬럼) 이름 변경 : 구별, 인구수, 한국인, 외국인, 고령자

# %%
pop_Seoul.rename(columns = {pop_Seoul.columns[0] : '구별',
                           pop_Seoul.columns[1] : '인구수',
                           pop_Seoul.columns[2] : '한국인',
                           pop_Seoul.columns[3] : '외국인',
                           pop_Seoul.columns[4] : '고령자'}, inplace=True)
pop_Seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 0   합계  10013781  9733655  280126  1518239
# 1  종로구    161984   151217   10767    28073
# 2   중구    136469   126175   10294    23794
# 3  용산구    246165   229579   16586    39439
# 4  성동구    307193   299042    8151    44728

# %%
# 합계 행을 삭제
pop_Seoul.drop([0], inplace=True)
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  161984  151217  10767  28073
# 2   중구  136469  126175  10294  23794
# 3  용산구  246165  229579  16586  39439
# 4  성동구  307193  299042   8151  44728
# 5  광진구  365990  350417  15573  48989

# %%
pop_Seoul.tail()
# Out:
#      구별     인구수     한국인    외국인    고령자
# 21  관악구  516662  499374  17288  76664
# 22  서초구  434801  430568   4233  58332
# 23  강남구  549898  544804   5094  72602
# 24  송파구  680883  674095   6788  89539
# 25  강동구  457042  452646   4396  66401

# %% [markdown]
# ## CCTV 현황

# %%
# CCTV에서 소계로 오름차순 정렬
CCTV_Seoul.sort_values(by = '소계', ascending=True).head()
# Out:
#      구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 9   도봉구   858     197.0   66.0    8.0    185     59    155    117     71
# 24  중랑구  1068       0.0    0.0    0.0    770    102    121     66      9
# 2   강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 22  종로구  1471       8.0    7.0  599.0    132    195    148    281    101
# 23   중구  1544      25.0  165.0  114.0     80    245    270    317    328

# %% [markdown]
# CCTV댓수가 적은 지역으로는 도봉구, 중랑구, 강북구, 종로구, 중구 순이다.

# %%
# CCTV에서 소계로 내림차순 정렬
CCTV_Seoul.sort_values(by = '소계', ascending=False).head()
# Out:
#      구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0   강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 4   관악구  3985     430.0   56.0  419.0    487    609    619    694    671
# 6   구로구  3227     852.0  219.0  349.0    187    268    326    540    486
# 16  성북구  3003     779.0   84.0  304.0    241    279    388    285    643
# 21  은평구  2962    1365.0   83.0   99.0    343    180    296    229    367

# %% [markdown]
# CCTV댓수가 많은 지역으로는 강남구, 관악구, 구로구, 성북구, 은평구 순이다.

# %% [markdown]
# ### 3년간 CCTV 증가율을 구해서 CCTV가 제일 많이 증가한 구를 계산

# %%
#최근 증가율 : 최근 3년치 CCTV댓수(2016~2018)
#나누어 100을 곱한다.

#최근 증가율이란 컬럼을 만들어 Data 넣기
CCTV_Seoul['최근 증가율'] = (CCTV_Seoul['2016년'] + CCTV_Seoul['2017년'] + CCTV_Seoul['2018년']) / CCTV_Seoul['소계'] *100
CCTV_Seoul.sort_values(by='최근 증가율', ascending = False).head()
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 23    중구  1544      25.0  165.0  114.0     80    245    270    317    328
# 19  영등포구  2495     132.0  121.0  206.0    217    366    289    371    793
# 15   성동구  2679     665.0  109.0  118.0    101    258    201    933    294
# 7    금천구  1634      27.0   17.0  242.0    101    382    136    199    530
# 5    광진구  1581     470.0   42.0   83.0     87     64     21    468    346
#
#        최근 증가율
# 23  59.261658
# 19  58.236473
# 15  53.303471
# 7   52.937576
# 5   52.814674

# %% [markdown]
# 결과를 보면 최근 3년간의 CCTV가 2015년 이전에 비해 가장 많이 증가한 곳은
# 중구, 영등포구, 성동구, 금천구, 광진구 순이다.

# %%
# 구별 항목의 유일성 확인
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
len(pop_Seoul['구별'].unique())
# Out:
# 25

# %%
#고령자 비율과 외국인 비율 계산 후 적용
#외국인 비율, 고령자 비율

pop_Seoul['외국인 비율'] = (pop_Seoul['외국인']/pop_Seoul['인구수']*100)
pop_Seoul['고령자 비율'] = (pop_Seoul['고령자']/pop_Seoul['인구수']*100)
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 1  종로구  161984  151217  10767  28073  6.646953  17.330724
# 2   중구  136469  126175  10294  23794  7.543105  17.435462
# 3  용산구  246165  229579  16586  39439  6.737757  16.021368
# 4  성동구  307193  299042   8151  44728  2.653381  14.560228
# 5  광진구  365990  350417  15573  48989  4.255034  13.385338

# %%
# 인구수 내림차순 정렬
pop_Seoul.sort_values(by='인구수', ascending=False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 24  송파구  680883  674095   6788  89539  0.996941  13.150424
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 23  강남구  549898  544804   5094  72602  0.926354  13.202812
# 11  노원구  535495  531037   4458  82682  0.832501  15.440294
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
# 외국인 내림차순 정렬
pop_Seoul.sort_values(by='외국인', ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 21   관악구  516662  499374  17288  76664  3.346095  14.838328
# 6   동대문구  362793  346156  16637  60367  4.585811  16.639516

# %%
#외국인 비율 정렬
pop_Seoul.sort_values(by='외국인 비율', ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 2     중구  136469  126175  10294  23794  7.543105  17.435462
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 3    용산구  246165  229579  16586  39439  6.737757  16.021368

# %% [markdown]
# (정리)<br>
# 인구수가 제일 많은 지역은 송파구이지만, 외국인은 영등포구가 제일 많다.<br>
# 그리고 그 근처라고 할 수 있는 구로구, 금천구 등도 외국인이 많이 산다.<br>
# 송파구는 고령자가 제일 많지만 고령자의 비뮹ㄹ이 높지 않은것으로 확인된다.<br>
# 하지만 강북구, 종로구, 중구, 도봉구, 은평구 같은 경우는 인구수 대비<br>
# 고령자 비율이 많기 때문에 추후 고령화가 우려된다.

# %%
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 1  종로구  161984  151217  10767  28073  6.646953  17.330724
# 2   중구  136469  126175  10294  23794  7.543105  17.435462
# 3  용산구  246165  229579  16586  39439  6.737757  16.021368
# 4  성동구  307193  299042   8151  44728  2.653381  14.560228
# 5  광진구  365990  350417  15573  48989  4.255034  13.385338

# %%
CCTV_Seoul.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671
#
#       최근 증가율
# 0  34.284620
# 1  45.343268
# 2  45.375494
# 3  43.784787
# 4  49.786700

# %%
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on='구별')
data_result.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671
#
#       최근 증가율     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 0  34.284620  549898  544804   5094  72602  0.926354  13.202812
# 1  45.343268  457042  452646   4396  66401  0.961837  14.528424
# 2  45.375494  316750  312985   3765  61660  1.188635  19.466456
# 3  43.784787  595703  589302   6401  85992  1.074529  14.435381
# 4  49.786700  516662  499374  17288  76664  3.346095  14.838328

# %%
# 반복문을 이용한 년도별 CCTV 컬럼 삭제
delColumn = data_result.columns[2:10]

for i in delColumn:
    del data_result[i]
    
data_result.head()
# Out:
#     구별    소계     최근 증가율     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 0  강남구  5221  34.284620  549898  544804   5094  72602  0.926354  13.202812
# 1  강동구  1879  45.343268  457042  452646   4396  66401  0.961837  14.528424
# 2  강북구  1265  45.375494  316750  312985   3765  61660  1.188635  19.466456
# 3  강서구  1617  43.784787  595703  589302   6401  85992  1.074529  14.435381
# 4  관악구  3985  49.786700  516662  499374  17288  76664  3.346095  14.838328

# %%
# 인덱스 변경하기

data_result.set_index('구별', inplace=True)
data_result.head()
# Out:
#        소계     최근 증가율     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 구별
# 강남구  5221  34.284620  549898  544804   5094  72602  0.926354  13.202812
# 강동구  1879  45.343268  457042  452646   4396  66401  0.961837  14.528424
# 강북구  1265  45.375494  316750  312985   3765  61660  1.188635  19.466456
# 강서구  1617  43.784787  595703  589302   6401  85992  1.074529  14.435381
# 관악구  3985  49.786700  516662  499374  17288  76664  3.346095  14.838328

# %% [markdown]
# # 상관계수
# - 상관계수의 절대값이 0.3이하 : 무시
# - 상관계수의 절대값이 0.3이상 : 약한 상관관계
# - 상관계수의 절대값이 0.7이상 : 뚜렷한 상관관계

# %%
#CCTV 소계와 고령자 비율의 상관계수
np.corrcoef(data_result['고령자 비율'], data_result['소계'])
# Out:
# array([[ 1.        , -0.44225083],
#        [-0.44225083,  1.        ]])

# %%
#CCTV 소계와 외국인 비율의 상관계수
np.corrcoef(data_result['외국인 비율'], data_result['소계'])
# Out:
# array([[ 1.        , -0.06215538],
#        [-0.06215538,  1.        ]])

# %%
#CCTV 소계와 인구수 상관계수
np.corrcoef(data_result['인구수'], data_result['소계'])
# Out:
# array([[1.        , 0.38064812],
#        [0.38064812, 1.        ]])

# %% [markdown]
# (결론)<br>
# 고령자 비율, 외국인 비율, 인구수를 비교 해보았을때 고령자 비율과는 음의 상관이 발생하고,<br>
# 인구수와 소계는 양의 상관이 있다.

# %% [markdown]
# ## 시각화

# %%
# 한글 폰트 문제 해결
# os 정보

import platform

#font_manager : 포늩 관리 모듈
#rc : 폰트 변경 모듈
from matplotlib import font_manager, rc

# 시각화 도구
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin' :
    rc('font', family='AppleGothic') #os가 mac
elif platform.sysotem() == 'Windows' :
    path = 'c:\Windows\Fonts\malgun.ttf' #os가 windows
    font_name = font_manager.FontProperties(frame=path).get_name()
    rc('font', family=font_name)
else : 
    print("Unknown System")

# %%
# 정리가 되었으니 새로운 CSV file로 저장
data_result.to_csv("../Data/CCTV_Result.csv")

# %%
#plot 그리기
data_result.plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
#장렬 후 다시 그리기
data_result['소계'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %% [markdown]
# ### 인구 대비 CCTV 비율

# %%
# CCTV비율이란 컬럼으로 생성하여 계산후에 막대그래프로 정렬하여 그리기

data_result['CCTV비율'] = data_result['소계'] / data_result['인구수'] * 100

data_result['CCTV비율'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
# 산점도를 이용한 시각화
plt.figure(figsize=(6,6))
plt.scatter(data_result['인구수'], data_result['소계'])
plt.xlabel('인구수')
plt.ylabel('소계')
plt.show()

# %%
# 인구수, 소계에 따른 기준선(회귀선, 평균선) 만들기
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)
fp1
# Out:
# array([2.88522756e-03, 1.06403852e+03])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000)

plt.figure(figsize=(10,10))
plt.scatter(data_result['인구수'], data_result['소계'])
plt.plot(fx,f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('소계')
plt.grid()
plt.show()

# %% [raw]
# (결론)
# 이 직선은 CCTV댓수의 기준값이 됩니다.
# 이 직선을 기준으로 상위에 있는 점은 과하게 설치된 것이고
# 직선 보다 하위에 있는 점은 인구수에 비해 CCTV가 부족하다는 해석입니다.

# %%
# 기준선 구하기
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)

# y축 : CCTV 기준치 구하기
f1 = np.poly1d(fp1)

# x축 : 인구수
fx = np.linspace(100000, 700000)

# 소계에서 기준 인구수 차이로 오차값 구하기
data_result['오차'] = np.abs(data_result['소계'] - f1(data_result['인구수']))

# 정렬
df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.head()
# Out:
#        소계     최근 증가율     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율  \
# 구별
# 강남구  5221  34.284620  549898  544804   5094  72602  0.926354  13.202812
# 송파구  1586  38.587642  680883  674095   6788  89539  0.996941  13.150424
# 관악구  3985  49.786700  516662  499374  17288  76664  3.346095  14.838328
# 도봉구   858  39.976690  333495  331238   2257  60023  0.676772  17.998171
# 강서구  1617  43.784787  595703  589302   6401  85992  1.074529  14.435381
#
#        CCTV비율           오차
# 구별
# 강남구  0.949449  2570.380612
# 송파구  0.232933  1442.540920
# 관악구  0.771297  1430.274035
# 도봉구  0.257275  1168.247488
# 강서구  0.271444  1165.777237

# %%
# 그래프에 Text와 Color

plt.figure(figsize=(14,10))
plt.scatter(data_result['인구수'], data_result['소계'], c=data_result['오차'])

# x축 : 기준 인구수, y축: CCTV 대수
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')
# 오차가 가장 큰 10개 구에 텍스트 붙이기
for n in range(10) :
    plt.text(df_sort['인구수'][n]*1.02, df_sort['소계'][n]*0.98, df_sort.index[n])

plt.colorbar()
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()
